# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/train.csv')

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          20       RL        141.0    31770   Pave   NaN      IR1
# 1   2          20       RH         80.0    11622   Pave   NaN      Reg
# 2   3          20       RL         81.0    14267   Pave   NaN      IR1
# 3   4          20       RL         93.0    11160   Pave   NaN      Reg
# 4   5          60       RL         74.0    13830   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 2         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 3         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 4         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
cat_vars = df.select_dtypes(include=['object'])
cat_vars.head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 1       RH   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 3       RL   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0        NAmes       Norm       Norm     1Fam     1Story       Hip  CompShg
# 1        NAmes      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2        NAmes       Norm       Norm     1Fam     1Story       Hip  CompShg
# 3        NAmes       Norm       Norm     1Fam     1Story       Hip  CompShg
# 4      Gilbert       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
cat_vars.shape
# Out:
# (2930, 43)

# %%
missing_variable_per = cat_vars.isnull().mean()*100

missing_variable_per
# Out:
# MSZoning          0.000000
# Street            0.000000
# Alley            93.242321
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType       60.580205
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.730375
# BsmtCond          2.730375
# BsmtExposure      2.832765
# BsmtFinType1      2.730375
# BsmtFinType2      2.764505
# Heating           0.000000
# HeatingQC         0.000000
# CentralAir        0.000000
# Electrical        0.034130
# KitchenQual       0.000000
# Functional        0.000000
# FireplaceQu      48.532423
# GarageType        5.358362
# ...

# %%
missing_variable_column = missing_variable_per[missing_variable_per>20].keys()
missing_variable_column
# Out:
# Index(['Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
df2 = cat_vars.drop(missing_variable_column,axis=1)
df2.head()
# Out:
#   MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 1       RH   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 2       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 3       RL   Pave      Reg         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0        NAmes       Norm       Norm     1Fam     1Story       Hip  CompShg
# 1        NAmes      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2        NAmes       Norm       Norm     1Fam     1Story       Hip  CompShg
# 3        NAmes       Norm       Norm     1Fam     1Story       Hip  CompShg
# 4      Gilbert       Norm       Norm     1Fam     2Story     Gable  CompShg
#
#   Exterior1st Exterior2nd ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# ...

# %%
df2.shape
# Out:
# (2930, 37)

# %%
df.shape
# Out:
# (2930, 81)

# %%
isnull_per = df2.isnull().mean()*100
isnull_per
# Out:
# MSZoning         0.000000
# Street           0.000000
# LotShape         0.000000
# LandContour      0.000000
# Utilities        0.000000
# LotConfig        0.000000
# LandSlope        0.000000
# Neighborhood     0.000000
# Condition1       0.000000
# Condition2       0.000000
# BldgType         0.000000
# HouseStyle       0.000000
# RoofStyle        0.000000
# RoofMatl         0.000000
# Exterior1st      0.000000
# Exterior2nd      0.000000
# ExterQual        0.000000
# ExterCond        0.000000
# Foundation       0.000000
# BsmtQual         2.730375
# BsmtCond         2.730375
# BsmtExposure     2.832765
# BsmtFinType1     2.730375
# BsmtFinType2     2.764505
# Heating          0.000000
# HeatingQC        0.000000
# CentralAir       0.000000
# Electrical       0.034130
# KitchenQual      0.000000
# Functional       0.000000
# GarageType       5.358362
# GarageFinish     5.426621
# GarageQual       5.426621
# GarageCond       5.426621
# PavedDrive       0.000000
# ...

# %%
miss_vars = isnull_per[isnull_per>0].keys()
miss_vars
# Out:
# Index(['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'],
#       dtype='object')

# %%
df2['GarageCond'].mode()    ## show mode value
# Out:
# 0    TA
# Name: GarageCond, dtype: object

# %%
df2['GarageCond'].value_counts()    ## show count of each value
# Out:
# GarageCond
# TA    2665
# Fa      74
# Gd      15
# Po      14
# Ex       3
# Name: count, dtype: int64

# %%
df2['GarageCond'].fillna(df2['GarageCond'].mode()[0])
# Out:
# 0       TA
# 1       TA
# 2       TA
# 3       TA
# 4       TA
# 5       TA
# 6       TA
# 7       TA
# 8       TA
# 9       TA
# 10      TA
# 11      TA
# 12      TA
# 13      TA
# 14      TA
# 15      TA
# 16      TA
# 17      TA
# 18      TA
# 19      TA
# 20      TA
# 21      TA
# 22      TA
# 23      TA
# 24      TA
# 25      TA
# 26      TA
# 27      TA
# 28      TA
# 29      TA
# 30      TA
# 31      TA
# 32      TA
# 33      TA
# 34      TA
# 35      TA
# 36      TA
# 37      TA
# 38      TA
# 39      TA
# 40      TA
# 41      TA
# 42      TA
# 43      TA
# 44      TA
# 45      TA
# 46      TA
# 47      TA
# 48      TA
# 49      TA
# 50      TA
# 51      TA
# 52      TA
# 53      TA
# 54      TA
# 55      TA
# 56      TA
# 57      TA
# 58      TA
# 59      TA
# 60      TA
# 61      TA
# 62      TA
# 63      TA
# 64      TA
# 65      TA
# 66      TA
# 67      TA
# 68      TA
# 69      TA
# 70      TA
# 71      TA
# 72      TA
# 73      TA
# 74      TA
# 75      TA
# ...

# %%
df2['GarageCond'].isnull().sum()
# Out:
# 159

# %%
##df.to_csv('clean_data.csv',index=False)
##df2.to_csv('clean_data2.csv',index=False)

# %%
plt.figure(figsize=(25,25))
for i,var in enumerate(miss_vars):
  plt.subplot(4,3,i+1)
  plt.hist(df2[var],bins=20,label = 'Imput')
  plt.hist(df[var].dropna(),bins=20,alpha=0.5,label = 'Original')
  plt.legend()
  plt.title(var)
plt.show()

# %%
df.update(df2)
df.drop(columns=miss_vars,inplace=True)

# %%
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          20       RL        141.0    31770   Pave   NaN      IR1
# 1        2          20       RH         80.0    11622   Pave   NaN      Reg
# 2        3          20       RL         81.0    14267   Pave   NaN      IR1
# 3        4          20       RL         93.0    11160   Pave   NaN      Reg
# 4        5          60       RL         74.0    13830   Pave   NaN      IR1
# 5        6          60       RL         78.0     9978   Pave   NaN      IR1
# 6        7         120       RL         41.0     4920   Pave   NaN      Reg
# 7        8         120       RL         43.0     5005   Pave   NaN      IR1
# 8        9         120       RL         39.0     5389   Pave   NaN      IR1
# 9       10          60       RL         60.0     7500   Pave   NaN      Reg
# 10      11          60       RL         75.0    10000   Pave   NaN      IR1
# ...
